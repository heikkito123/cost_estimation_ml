# %%
import pandas as pd

# %%
df = pd.read_excel("001 Laskentapohja, 2024.xlsx", sheet_name='Eritelysivu')

# %%
df.to_dict(orient='records')
# Out:
# [{'Urakka': 'Tilaaja',
#   'Tekniikantie 4 2. krs.': 0,
#   'Unnamed: 2': nan,
#   'Unnamed: 3': nan,
#   'Unnamed: 4': nan,
#   'Unnamed: 5': nan,
#   'Unnamed: 6': nan},
#  {'Urakka': nan,
#   'Tekniikantie 4 2. krs.': nan,
#   'Unnamed: 2': nan,
#   'Unnamed: 3': nan,
#   'Unnamed: 4': nan,
#   'Unnamed: 5': nan,
#   'Unnamed: 6': nan},
#  {'Urakka': nan,
#   'Tekniikantie 4 2. krs.': nan,
#   'Unnamed: 2': nan,
#   'Unnamed: 3': nan,
#   'Unnamed: 4': nan,
#   'Unnamed: 5': nan,
#   'Unnamed: 6': 'Syötä hinnoitteluhinta tuntiarviota varten '},
#  {'Urakka': 'Koonti',
#   'Tekniikantie 4 2. krs.': nan,
#   'Unnamed: 2': nan,
#   'Unnamed: 3': nan,
#   'Unnamed: 4': nan,
#   'Unnamed: 5': 'Hinnoitteluhinta n. ',
#   'Unnamed: 6': 42},
#  {'Urakka': nan,
#   'Tekniikantie 4 2. krs.': nan,
#   'Unnamed: 2': nan,
#   'Unnamed: 3': nan,
#   'Unnamed: 4': nan,
#   'Unnamed: 5': nan,
#   'Unnamed: 6': nan},
#  {'Urakka': 'Tuntihinnoittelut',
#   'Tekniikantie 4 2. krs.': 'Hinta',
# ...
