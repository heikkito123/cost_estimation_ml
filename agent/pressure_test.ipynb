# %% [markdown]
# ### PRESSURETESTING: RUNNING TRIAGE AGENT AND A SUB-AGENT
#
# Doing inference with 2 x gemma4:e4b with context-window 130K on windows 11, Intel(R) Core(TM) i7-10850H CPU @ 2.70GHz 2.71 GHz, 48,0 Gt RAM, Nvidia Quadro RTX 3000 GPU
#
# I initially tried just piping the raw pdf-to-text-input to two 130K context models, and it freezes evaluating the prompt. Next up, chunking the text.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
